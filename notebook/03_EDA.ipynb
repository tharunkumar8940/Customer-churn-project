# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("customer_churn_clean.csv")

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges  TotalCharges ContractType  \
# 0        1001   29  Female       9           60.41        543.69     One year
# 1        1002   45  Female      56           88.60       4961.60     One year
# 2        1003   22    Male      70           40.74       2851.80     One year
# 3        1004   35  Female      45           58.47       2631.15     One year
# 4        1005   39  Female      16           99.45       1591.20     Two year
#
#   InternetService TechSupport     PaymentMethod  MonthlyUsageGB  \
# 0     Fiber optic         Yes       Credit Card             164
# 1             DSL         Yes  Electronic Check              47
# 2             DSL         Yes              Cash             166
# 3             DSL          No       Credit Card              87
# 4             DSL          No  Electronic Check             190
#
#    NumComplaints Churn
# 0              0    No
# 1              0    No
# 2              4    No
# 3              5    No
# 4              3    No

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.describe()
# Out:
#         CustomerID          Age       Tenure  MonthlyCharges  TotalCharges  \
# count  1000.000000  1000.000000  1000.000000     1000.000000   1000.000000
# mean   1500.500000    43.025000    35.289000       81.179490   2858.690670
# std     288.819436    13.046555    20.526491       22.697335   1905.919277
# min    1001.000000    21.000000     1.000000       40.010000     55.850000
# 25%    1250.750000    32.000000    18.000000       61.497500   1330.035000
# 50%    1500.500000    43.000000    33.000000       82.135000   2584.690000
# 75%    1750.250000    54.000000    52.250000      100.530000   4118.625000
# max    2000.000000    65.000000    72.000000      119.930000   8178.490000
#
#        MonthlyUsageGB  NumComplaints
# count     1000.000000    1000.000000
# mean       145.613000       2.444000
# std         61.857899       1.712833
# min         40.000000       0.000000
# 25%         90.000000       1.000000
# 50%        145.000000       2.500000
# 75%        198.250000       4.000000
# max        250.000000       5.000000

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])

correlation = numeric_df.corr()

correlation
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges  \
# CustomerID        1.000000 -0.045683  0.015692        0.009294      0.015322
# Age              -0.045683  1.000000  0.060549       -0.022198      0.048230
# Tenure            0.015692  0.060549  1.000000       -0.013004      0.870234
# MonthlyCharges    0.009294 -0.022198 -0.013004        1.000000      0.415130
# TotalCharges      0.015322  0.048230  0.870234        0.415130      1.000000
# MonthlyUsageGB   -0.023634 -0.028945  0.016604       -0.009537      0.013216
# NumComplaints     0.003907  0.049359 -0.002628        0.012481      0.006064
#
#                 MonthlyUsageGB  NumComplaints
# CustomerID           -0.023634       0.003907
# Age                  -0.028945       0.049359
# Tenure                0.016604      -0.002628
# MonthlyCharges       -0.009537       0.012481
# TotalCharges          0.013216       0.006064
# MonthlyUsageGB        1.000000       0.038082
# NumComplaints         0.038082       1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.imshow(correlation)

plt.colorbar()

plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)

plt.yticks(range(len(correlation.columns)), correlation.columns)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Age"], bins=10)

plt.title("Age Distribution")

plt.xlabel("Age")

plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["MonthlyCharges"], bins=10)

plt.title("Monthly Charges")

plt.show()

# %%
df["Churn"].value_counts().plot(kind="bar")

plt.title("Customer Churn")

plt.show()

# %%
df["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%")

plt.ylabel("")

plt.title("Gender Distribution")

plt.show()

# %%
df["ContractType"].value_counts().plot(kind="bar")

plt.title("Contract Types")

plt.show()

# %%
df["InternetService"].value_counts().plot(kind="bar")

plt.title("Internet Service")

plt.show()

# %%
df.nlargest(10, "MonthlyCharges")
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges  TotalCharges  \
# 353        1354   48  Female       2          119.93        239.86
# 691        1692   26  Female      19          119.93       2278.67
# 239        1240   53  Female      18          119.90       2158.20
# 405        1406   61    Male      68          119.89       8152.52
# 312        1313   37  Female       1          119.83        119.83
# 785        1786   59  Female      36          119.78       4312.08
# 959        1960   25  Female      67          119.72       8021.24
# 558        1559   65    Male      67          119.71       8020.57
# 287        1288   31  Female      34          119.70       4069.80
# 547        1548   50  Female      31          119.65       3709.15
#
#        ContractType InternetService TechSupport     PaymentMethod  \
# 353  Month-to-month             DSL         Yes       Credit Card
# 691        Two year     Fiber optic         Yes  Electronic Check
# 239        One year     Fiber optic          No     Bank Transfer
# 405  Month-to-month             DSL          No     Bank Transfer
# 312  Month-to-month     Fiber optic         Yes     Bank Transfer
# 785        One year     Fiber optic          No  Electronic Check
# 959        One year             DSL          No     Bank Transfer
# 558        Two year             DSL          No       Credit Card
# 287        One year             DSL         Yes              Cash
# 547        Two year     Fiber optic         Yes  Electronic Check
#
#      MonthlyUsageGB  NumComplaints Churn
# 353             229              3   Yes
# 691             230              3    No
# 239             222              0    No
# 405             206              5    No
# 312              67              3   Yes
# 785             209              1    No
# 959              83              0    No
# 558              77              4    No
# 287              68              1    No
# 547             171              2    No
